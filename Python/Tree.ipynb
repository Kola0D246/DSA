# %%
class Tree:
    def __init__(self, num_sibling=2, sorted=True, balanced=False):
        self.tree = []

    def addnode(self, node):
        if not sorted:
            self.tree.append(node)
        elif node not in self.tree:
            self.tree.append(node)

    def show(self):
        print(' '*2*len(self.tree)+str(self.tree[0]))
        for node in self.tree.append(node)

T1 = Tree()
T1.addnode(2)
T1.show()
# Out:
#   2
